# %%
#importing the libraries needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Loading the Covid_vaccines Dataset

# %%
covid_vaccines = pd.read_csv("covid19vaccinesadministeredbydemographics.csv")
covid_vaccines
# Out:
#      demographic_category demographic_value administered_date  total_doses  \
# 0               Age Group             18-49        2022-03-08         8219
# 1               Age Group             50-64        2022-03-08         2937
# 2               Age Group               65+        2022-03-08         1951
# 3               Age Group             12-17        2022-03-08         1919
# 4               Age Group              5-11        2022-03-08         3298
# ...                   ...               ...               ...          ...
# 9612               Gender              Male        2020-03-03            1
# 9613       Race/Ethnicity             Asian        2020-03-03            1
# 9614            Age Group             18-49        2020-01-05            1
# 9615               Gender              Male        2020-01-05            1
# 9616       Race/Ethnicity            Latino        2020-01-05            1
#
# ...

# %%
covid_vaccines.head()
# Out:
#   demographic_category demographic_value administered_date  total_doses  \
# 0            Age Group             18-49        2022-03-08         8219
# 1            Age Group             50-64        2022-03-08         2937
# 2            Age Group               65+        2022-03-08         1951
# 3            Age Group             12-17        2022-03-08         1919
# 4            Age Group              5-11        2022-03-08         3298
#
#    cumulative_total_doses  pfizer_doses  cumulative_pfizer_doses  \
# 0                33212597          5311                 19574942
# 1                16332473          1651                  8659419
# 2                14770183           973                  6934877
# 3                 5213509          1905                  5192333
# 4                 2484587            67                    38657
#
#    moderna_doses  cumulative_moderna_doses  jj_doses  cumulative_jj_doses  \
# ...

# %% [markdown]
# ## Loading the Covid_data Dataset

# %%
covid_data = pd.read_csv("covid19vaccinesbycounty.csv")
covid_data
# Out:
#         county administered_date  total_doses  cumulative_total_doses  \
# 0      Alameda        2020-01-05            0                       0
# 1      Alameda        2020-03-03            0                       0
# 2      Alameda        2020-07-27            0                       0
# 3      Alameda        2020-07-29            0                       1
# 4      Alameda        2020-07-30            0                       1
# ...        ...               ...          ...                     ...
# 36699     Yuba        2022-03-04           85                   91482
# 36700     Yuba        2022-03-05           42                   91524
# 36701     Yuba        2022-03-06           19                   91543
# 36702     Yuba        2022-03-07           52                   91595
# 36703     Yuba        2022-03-08           25                   91620
#
#        pfizer_doses  cumulative_pfizer_doses  moderna_doses  \
# 0                 0                        0              0
# ...
